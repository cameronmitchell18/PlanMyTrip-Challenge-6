# %%
import pandas as pd 

from citipy import citipy

from config import weather_api_key

from datetime import datetime

import random

import numpy as np

import requests

import time

# %%
# 1) Generate 2,000 random lat and lng 

lats = np.random.uniform(-90 , 90 , size = 2000)

long = np.random.uniform(-180 , 180 , size = 2000)

lat_langs = zip(lats , long)

coordinates = list(lat_langs)

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# tiksi ru
# rikitea pf
# touros br
# bathsheba bb
# kapaa us
# fevralsk ru
# clyde river ca
# kendrapara in
# kerchevskiy ru
# rundu na
# taolanaro mg
# manono cd
# hasaki jp
# new norfolk au
# severodvinsk ru
# bubaque gw
# faanui pf
# artyk ru
# busselton au
# albany au
# pochutla mx
# labuhan id
# kruisfontein za
# cabo san lucas mx
# kavieng pg
# bousso td
# chifeng cn
# ponta do sol cv
# kapaa us
# taolanaro mg
# busselton au
# lavrentiya ru
# ushuaia ar
# hilo us
# tuktoyaktuk ca
# kapaa us
# college us
# keokuk us
# qaanaaq gl
# comodoro rivadavia ar
# qaanaaq gl
# samusu ws
# pisco pe
# atuona pf
# albany au
# srednekolymsk ru
# cabedelo br
# larreynaga ni
# punta arenas cl
# kapaa us
# georgetown sh
# hambantota lk
# skjervoy no
# hilo us
# taolanaro mg
# san cristobal ec
# yamada jp
# semme sn
# mar del plata ar
# makakilo city us
# busselton au
# albany au
# upernavik gl
# alpatovo ru
# chuy uy
# basoko cd
# cape town za
# dunedin nz
# bengkulu id
# sao felix do xingu br
# ...

# %%
cities = []

# Identify the nearest city for each lat and lang combination 

for coordinate in coordinates:

    city = citipy.nearest_city(coordinate[0] , coordinate[1]).city_name

    #If the the city is unique, then add it to the list of citites 

    if city not in cities:

        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_url = url + '&q=' + 'Grand Rapids'

city_weather = requests.get(city_url)

if city_weather.status_code == 200:

    print(f'City Weather Was Found')

else:

    print(f'City Weather Was Not Found')

grand_rapids_data = city_weather.json()
# Out:
# City Weather Was Found

# %%
grand_rapids_data['sys']
# Out:
# {'type': 2,
#  'id': 2005020,
#  'country': 'US',
#  'sunrise': 1650624571,
#  'sunset': 1650673946}

# %%
lat = grand_rapids_data["coord"]["lat"]
lng = grand_rapids_data["coord"]["lon"]
max_temp = grand_rapids_data["main"]["temp_max"]
humidity = grand_rapids_data["main"]["humidity"]
clouds = grand_rapids_data["clouds"]["all"]
wind = grand_rapids_data["wind"]["speed"]
current_weather = grand_rapids_data["weather"][0]['main']
current_description = grand_rapids_data["weather"][0]['description']
print(lat, lng, max_temp, humidity, clouds, wind, current_weather, current_description)
# Out:
# 42.9634 -85.6681 51.55 77 100 11.5 Rain moderate rain

# %%
date = grand_rapids_data['dt']

# Converting the UTC date to a date format with year, month, day, hours, minutes, and seconds.

datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-04-22 17:34:47'

# %%
import time

from datetime import datetime

from citipy import citipy


city_data = []

# Begining of logging 

print('Beginning Data Retriveal      ')

print('------------------------------')

# Counters NOTE: initialized the counters at 1 
# because we want the first iteration of the logging for each recorded response and the set to start at 1.

record_count = 1

set_count = 1 

# Looping through the citites 

for i, city in enumerate(cities):

    # Groupping cities in sets of 50 

    if (i % 50 == 0 and i >= 50):

        set_count += 1 

        record_count = 1 

        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather= city_weather["weather"][0]['main']
        weather_description = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather" : weather,
                          'Weather Description' : weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retriveal
# ------------------------------
# Processing Record 1 of Set 1 | tiksi
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | touros
# Processing Record 4 of Set 1 | bathsheba
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | kendrapara
# Processing Record 9 of Set 1 | kerchevskiy
# Processing Record 10 of Set 1 | rundu
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | manono
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | severodvinsk
# Processing Record 16 of Set 1 | bubaque
# Processing Record 17 of Set 1 | faanui
# Processing Record 18 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | albany
# ...

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)

new_column_order = ['City' , 'Country' , 'Lat' , 'Lng' , 'Max Temp' , 'Humidity' , 'Cloudiness' , 'Wind Speed' , 'Current Weather' , 'Weather Description']

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tiksi      RU  71.6872  128.8694     11.34        97         100
# 1      Rikitea      PF -23.1203 -134.9692     73.63        83         100
# 2       Touros      BR  -5.1989  -35.4608     81.21        76          96
# 3    Bathsheba      BB  13.2167  -59.5167     86.61        51          20
# 4        Kapaa      US  22.0752 -159.3190     76.98        82          75
# 5  Clyde River      CA  70.4692  -68.5914      5.23        78           0
# 6   Kendrapara      IN  20.5042   86.4160     80.46        84           0
# 7  Kerchevskiy      RU  59.9460   56.2884     24.87        94          84
# 8        Rundu      NA -17.9333   19.7667     63.59        49           0
# 9       Manono      CD  -7.3000   27.4167     74.44        79          71
#
#    Wind Speed Current Weather Weather Description
# 0        7.76            Snow          light snow
# 1       12.21            Rain       moderate rain
# ...

# %%
output_data_file = "weather_data/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
